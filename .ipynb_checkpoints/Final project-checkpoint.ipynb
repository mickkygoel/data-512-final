# %% [markdown]
# # A4: Final project preliminary proposal
# ## Mayank Goel
# ***November 2, 2020***

# %% [markdown]
# ### Motivation and problem statement

# %% [markdown]
# It would not be wrong to say that technology advancement is the leading factor for growth and development in the 21st century. Countries who lead in technical innovation are growing the fastest and people working within the tech industry are generally enjoying higher than average pay. Therefore, I wanted to understand the demographics of the building blocks of this technology industry, i.e. the developers. Analyzing the demographics of the developers around the world would help me draw conclusions about overall diversity and inclusion within this booming sector. For example, is technology advancement reaching every corner of the world, or is it clustered around a few pockets of the world? Is technology accessible and reachable to all genders and all races equally or does certain sections of the society still enjoy undue privileges? I would also like to examine how this social-economic trend evolving with time.
#
# This study would help to unearth the existing biases and inequality within the developer community. These biases and differences can be seen as a proxy of the developing world in general. Therefore, I believe that this study is deeply rooted as human-centered. Since our cohort is also a part of this community, I am hopeful that the analysis would help us realize our own prejudices and make us more aware of them as we go into the workforce. The study would help us to amend our behavior, make the required changes in our process and set new targets to improve the diversity, respect and inclusion within the developer community.

# %% [markdown]
# ### Data selected for analysis

# %% [markdown]
# The dataset that I plan to use for my analysis has been generated through the Stack Overflow Annual Developer Survey that was conducted by Stack Overflow from February 5 to February 28 in 2020. The data contains response of 65,000 professional and aspiring software developers, representing 186 countries around the world. The dataset contains information about the demographics of the respondents such as gender, nationality, ethnicity, years of experience, education, compensation, etc.  The survey was anonymous and does not contain any personally identifiable information.
#
# I plan to use this dataset as this provides very valuable data points that can directly answers the hypothesis that I plan to evaluate. Stack Overflow is used across the globe by all developers, therefore, I believe the dataset comes closest to the actual representation of the developers around the world.
#
# The dataset and related information can be accessed from this link: https://insights.stackoverflow.com/survey/
#
# Stack Overflow has allowed anyone to share, adapt, and create derivative works from the public 2020 Stack Overflow Developer Survey results as long as they attribute Stack Overflow. The dataset has been licensed under the Open Data Commons Open Database License (ODbL)
#
# Since the survey was done in February 2020, it is safe to assume that the dataset is free from the biases due to
# Covid-19  pandemic.  However, since the dataset is generated through a voluntary survey, there is a risk of selection bias. It is likely that a particular section of society is more likely or less likely to participate in a survey, and hence the dataset may not provide proportional representation for that particular section of society.
#
# The dataset contains 61 differnt fields entered by developers. Here is the glimpse of what all is included in the dataset.

# %%
import pandas as pd
df = pd.read_csv("survey_results_schema.csv")
df.head(15)
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3                      Age  What is your age (in years)? If you prefer not...
# 4               Age1stCode  At what age did you write your first line of c...
# 5                 CompFreq   Is that compensation weekly, monthly, or yearly?
# 6                CompTotal  What is your current total compensation (salar...
# 7            ConvertedComp  Salary converted to annual USD salaries using ...
# 8                  Country                                 Where do you live?
# 9             CurrencyDesc  Which currency do you use day-to-day? If your ...
# 10          CurrencySymbol  Which currency do you use day-to-day? If your ...
# 11  DatabaseDesireNextYear  Which database environments have you done exte...
# 12      DatabaseWorkedWith  Which database environments have you done exte...
# 13                 DevType  Which of the following describe you? Please se...
# 14                 EdLevel  Which of the following best describes the high...

# %% [markdown]
# ### Background and related work

# %% [markdown]
# It is no surprise that there are several discriminating biases against people from certain ethnicities, genders and sexualities. It is also well known that tech industry which is one of the most influential factors of development and growth is also rigged with such biases. This [Wikipedia article](https://en.wikipedia.org/wiki/Sexism_in_the_technology_industry#:~:text=Women%20in%20technology%20earn%20less,level%20women%20in%20Silicon%20Valley.) estimates that only about 17.6% of the undergraduate degrees were awarded to the women in 2011. It further states that the share of women employees in big tech firm is only about 30%. This ratio get even worse when we speak about senior executives. Therefore, it is important to study how this trend has shifted since 2015 in the tech industry. Are we moving in the right direction and at the right pace?
#
# However in addition to biases based on demographics, I was also interested in understanding the role of money in job satisfaction. The Glassdoor also conducted a [study](https://www.glassdoor.com/research/does-money-buy-happiness-the-link-between-salary-and-employee-satisfaction/#:~:text=Salary%20vs.&text=%5B1%5D%20At%20first%20glance%2C,less%20than%20%2430%2C000%20per%20year) in 2015 which highlights the importance of other factors such as culture, growth, leadership etc in job satisfaction. However, it concludes that money is still one of the most important factor in most job. Through this analysis, I will try to restablish the connection between compensation and job satisfaction based on 2020 dataset.

# %% [markdown]
# ### Research questions and hypothesis

# %% [markdown]
# In this project, I aim to answer and explore the following questions and hypothesis based on the above dataset:
#
# 1. Does money really bring job satisfcation? How does having higher compensation correlate with job satisfaction ? By exploring this question, I wish to comment on the motivating factors that work for humans. I assume that one does not necessarily has to rely completely on money for happiness, instead as a human one is looking for respect, work-life balance, joy and other such attributes in the job. This exploration would help us to corroborate above hypothesis.
#
# 2. Do people from certain ethnicities, genders and sexualities more likely to get a promotion relative to others? It is well recognized that certain sections of the society are exposed to low compensation despite the same work as others, however does this pay gap gets bigger as the person moves up the ladder, and does it affect the likelihood of person getting promoted? How is this trend changing with time.
#
# 3. Keeping the education level and years of experience same, do people from certain ethnicities, genders and sexualities exert more influence on what technologies their companies purchase? This question would shed light on the prevailing bias in the society based on demographics.

# %% [markdown]
# ### Methodology

# %% [markdown]
# In my analysis, I plan to make use of the descriptive analysis, historical trends as well correaltion matrices. I will also plan to borrow concepts from inferential statistics, and apply them as applicable. I would also clearly state my assumptions whereever required before drawing any conclusions.
#
# 1. **Descritive analysis** - Before I dive deep into the data, I would provide overall summary of the data and perform some descriptive analsyis. This descriptive analysis would help us to udnerstand the overview of the data and how does the situation looks today. This would provide us with aggragated measures usch as % of women in tech work force, compensation by gender, nationality etc.
#
# 2. **Historical analysis** - Since the Stack Overflow survey results are available for multiple years, I will try to related them together and produce the historical trends for metrics of choice. This kind of analysis would involve appending all the survey resutls files together and plotting metrics against the year. the anslysis would answer questions such as how has pay gap between gender change over time, how has influence based on ethnicities change over time etc.
#
# 3. **Regression analysis** - Yet another correlation analysis that I would like to produce is regression. This analysis can help in establishing the relationship of  Compensation with education, experience, gender, sexuality, ethnicity etc. Thus it can provide a very wholesome picure of exactly what all biases go into determining your analysis, and how much powerful each of those biases are.

# %% [markdown]
# ### Unknowns and dependencies

# %% [markdown]
# I would aim to balance all my course and plan in advance such that there are not surprises at the last moment and my workload is spread out. Therefore I am confident that I should be able to finish this project in the allotted time. However, there are some unknowns that may impact the delivery of the project.
# * Regulations around lockdown for covid-19 may change suddenly which may impact the time that we are able to devote towards the project.
# * Any special incidents such as laptop stopped working, or the course website getting down etc. can also have some minor delays in the project schedule.
# * Newly scheduled recrruitment events and career fairs may clash with the project deadline. Hence, spreading out the project work upfront would be very important.

# %% [markdown]
# ### Sources

# %% [markdown]
# * Stack Overflow. (n.d.). Retrieved November 03, 2020, from https://insights.stackoverflow.com/survey/
# * Stack Overflow Developer Survey 2020. (n.d.). Retrieved November 03, 2020, from https://insights.stackoverflow.com/survey/2020

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data/survey_results_public.csv")
df.head(15)
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1                     I am a developer by profession      Yes
# 1            2                     I am a developer by profession       No
# 2            3                        I code primarily as a hobby      Yes
# 3            4                     I am a developer by profession      Yes
# 4            5  I used to be a developer by profession, but no...      Yes
# 5            6                     I am a developer by profession       No
# 6            7                     I am a developer by profession      Yes
# 7            8                     I am a developer by profession      Yes
# 8            9                     I am a developer by profession       No
# 9           10                     I am a developer by profession      Yes
# 10          11                     I am a developer by profession      Yes
# 11          12                     I am a developer by profession       No
# 12          13  I am not primarily a developer, but I write co...      Yes
# 13          14                     I am a developer by profession      Yes
# 14          15             I am a student who is learning to code      Yes
#
#      Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0    NaN         13  Monthly        NaN            NaN             Germany
# 1    NaN         19      NaN        NaN            NaN      United Kingdom
# 2    NaN         15      NaN        NaN            NaN  Russian Federation
# 3   25.0         18      NaN        NaN            NaN             Albania
# 4   31.0         16      NaN        NaN            NaN       United States
# 5    NaN         14      NaN        NaN            NaN             Germany
# 6    NaN         18  Monthly        NaN            NaN               India
# 7   36.0         12   Yearly   116000.0       116000.0       United States
# 8   30.0         20      NaN        NaN            NaN             Tunisia
# 9   22.0         14   Yearly    25000.0        32315.0      United Kingdom
# 10  23.0         13   Yearly    31000.0        40070.0      United Kingdom
# 11  49.0         42  Monthly     1100.0        14268.0               Spain
# 12  53.0         14  Monthly     3000.0        38916.0         Netherlands
# 13  27.0         13   Yearly    66000.0        66000.0       United States
# 14   NaN         13      NaN        NaN            NaN              France
#
#             CurrencyDesc  ...                  SurveyEase  \
# 0          European Euro  ...  Neither easy nor difficult
# 1         Pound sterling  ...                         NaN
# 2                    NaN  ...  Neither easy nor difficult
# 3           Albanian lek  ...                         NaN
# 4                    NaN  ...                        Easy
# 5          European Euro  ...  Neither easy nor difficult
# 6   United States dollar  ...                         NaN
# 7   United States dollar  ...                        Easy
# 8   United States dollar  ...  Neither easy nor difficult
# 9         Pound sterling  ...                        Easy
# 10        Pound sterling  ...                        Easy
# 11         European Euro  ...                        Easy
# 12         European Euro  ...  Neither easy nor difficult
# 13  United States dollar  ...  Neither easy nor difficult
# 14                   NaN  ...                        Easy
#
#              SurveyLength Trans  \
# 0   Appropriate in length    No
# 1                     NaN   NaN
# 2   Appropriate in length   NaN
# 3                     NaN    No
# 4               Too short    No
# 5   Appropriate in length   NaN
# 6                     NaN   NaN
# 7   Appropriate in length    No
# 8   Appropriate in length    No
# 9   Appropriate in length    No
# 10  Appropriate in length    No
# 11  Appropriate in length    No
# 12               Too long    No
# 13  Appropriate in length    No
# 14  Appropriate in length    No
#
#                                        UndergradMajor  \
# 0   Computer science, computer engineering, or sof...
# 1   Computer science, computer engineering, or sof...
# 2                                                 NaN
# 3   Computer science, computer engineering, or sof...
# 4   Computer science, computer engineering, or sof...
# 5                                                 NaN
# 6   Computer science, computer engineering, or sof...
# 7   Computer science, computer engineering, or sof...
# 8   Computer science, computer engineering, or sof...
# 9                           Mathematics or statistics
# 10  Computer science, computer engineering, or sof...
# 11                          Mathematics or statistics
# 12                                                NaN
# 13  Computer science, computer engineering, or sof...
# 14  Computer science, computer engineering, or sof...
#
#      WebframeDesireNextYear                  WebframeWorkedWith  \
# 0              ASP.NET Core                ASP.NET;ASP.NET Core
# 1                       NaN                                 NaN
# 2                       NaN                                 NaN
# 3                       NaN                                 NaN
# 4      Django;Ruby on Rails                       Ruby on Rails
# 5                  React.js                                 NaN
# 6                       NaN                                 NaN
# 7    Django;React.js;Vue.js                               Flask
# 8                Angular.js                              jQuery
# 9              Flask;jQuery                        Flask;jQuery
# 10  Angular;Django;React.js  Angular;Angular.js;Django;React.js
# 11           ASP.NET;jQuery                      ASP.NET;jQuery
# 12                      NaN                                 NaN
# 13           Angular;Vue.js                      Angular;Vue.js
# 14                      NaN                                 NaN
#
#                                WelcomeChange WorkWeekHrs YearsCode  \
# 0    Just as welcome now as I felt last year        50.0        36
# 1   Somewhat more welcome now than last year         NaN         7
# 2   Somewhat more welcome now than last year         NaN         4
# 3   Somewhat less welcome now than last year        40.0         7
# 4    Just as welcome now as I felt last year         NaN        15
# 5                                        NaN         NaN         6
# 6      A lot more welcome now than last year         NaN         6
# 7    Just as welcome now as I felt last year        39.0        17
# 8    Just as welcome now as I felt last year        50.0         6
# 9   Somewhat more welcome now than last year        36.0         8
# 10   Just as welcome now as I felt last year        40.0        10
# 11   Just as welcome now as I felt last year        40.0         7
# 12     A lot less welcome now than last year        36.0        35
# 13   Just as welcome now as I felt last year        40.0         5
# 14   Just as welcome now as I felt last year         NaN         4
#
#    YearsCodePro
# 0            27
# 1             4
# 2           NaN
# 3             4
# 4             8
# 5             4
# 6             4
# 7            13
# 8             4
# 9             4
# 10            2
# 11            7
# 12           20
# 13            1
# 14          NaN
#
# [15 rows x 61 columns]

# %%
df.describe()
# Out:
#          Respondent           Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  64461.000000  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean   32554.079738     30.834111  3.190464e+242   1.037561e+05     40.782174
# std    18967.442360      9.585392            inf   2.268853e+05     17.816383
# min        1.000000      1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%    16116.000000     24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%    32231.000000     29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%    49142.000000     35.000000   1.250000e+05   9.500000e+04     44.000000
# max    65639.000000    279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df.corr()
# Out:
#                Respondent       Age  CompTotal  ConvertedComp  WorkWeekHrs
# Respondent       1.000000 -0.026741   0.000000      -0.005805    -0.003330
# Age             -0.026741  1.000000   0.044234       0.107002     0.050245
# CompTotal        0.000000  0.044234        NaN       0.000000    -0.000000
# ConvertedComp   -0.005805  0.107002   0.000000       1.000000     0.032612
# WorkWeekHrs     -0.003330  0.050245  -0.000000       0.032612     1.000000

# %%
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);
plt.savefig('heatmap.png', dpi=300, bbox_inches='tight')

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
#        'Trans', 'UndergradMajor', 'WebframeDesireNextYear',
#        'WebframeWorkedWith', 'WelcomeChange', 'WorkWeekHrs', 'YearsCode',
#        'YearsCodePro'],
#       dtype='object')

# %%
df.groupby(['JobSat'])['Respondent'].count().plot.bar()

# %%
sns.catplot(x="JobSat", y="ConvertedComp", kind="bar", data=df, height=8.27, aspect=11.7/8.27, order=['Very dissatisfied', 'Slightly dissatisfied', 'Neither satisfied nor dissatisfied', 'Slightly satisfied', 'Very satisfied'])

# %%
s1 = np.array(df[df.JobSat=='Very dissatisfied'].ConvertedComp)
s2 = np.array(df[df.JobSat=='Neither satisfied nor dissatisfied'].ConvertedComp)
s3 = np.array(df[df.JobSat=='Very satisfied'].ConvertedComp)

s1 = s1[~np.isnan(s1)]
s2 = s2[~np.isnan(s2)]
s3 = s3[~np.isnan(s3)]

# %%
np.mean(s1)
# Out:
# 98499.21848137536

# %%
np.mean(s2)
# Out:
# 91748.64535169699

# %%
np.mean(s3)
# Out:
# 119251.1183698727

# %%
from scipy.stats import ttest_ind
import numpy as np

ttest,pval = ttest_ind(s1,s2)
print("p-value",pval)
# Out:
# p-value 0.22193071397858374

# %%
ttest,pval = ttest_ind(s3,s2)
print("p-value",pval)
# Out:
# p-value 2.2568850967874774e-10

# %%
len(s2)
# Out:
# 4066

# %%
chart = sns.catplot(x="EdLevel", y="ConvertedComp", kind="bar", data=df, height=8.27, aspect=11.7/8.27)
chart.set_xticklabels(rotation=30)

# %%
df["YearsCode"].replace({"Less than 1 year": 0, "More than 50 years":50}, inplace=True)
df["YearsCode"] = df["YearsCode"].apply(pd.to_numeric)
df['Experience'] = (df.YearsCode//5)*5

# %%
sns.relplot(x="YearsCode", y="ConvertedComp", hue="Gender", data=df, height=8.27, aspect=11.7/8.27);

# %%
df_gender = df[df.Gender.isin(['Man','Woman','Non-binary, genderqueer, or gender non-conforming'])]
sns.lineplot(data=df_gender, x="Experience", y="ConvertedComp", err_style="bars", hue="Gender")

# %%
df_sexuality = df[df.Sexuality.isin(['Gay or Lesbian','Bisexual','Straight / Heterosexual'])]
sns.lineplot(data=df_sexuality, x="Experience", y="ConvertedComp", err_style=None, hue="Sexuality")

# %%
df1.reset
# Out:
#                                                               ConvertedComp
# YearsCode Gender
# 0.0       Man                                                  68588.870370
#           Non-binary, genderqueer, or gender non-conforming             NaN
#           Woman                                                35859.428571
# 1.0       Man                                                 115643.342857
#           Non-binary, genderqueer, or gender non-conforming    46890.666667
#           Woman                                                38704.205882
# 2.0       Man                                                  77276.956989
#           Non-binary, genderqueer, or gender non-conforming    36712.000000
#           Woman                                               110594.746988
# 3.0       Man                                                  55861.824828
#           Non-binary, genderqueer, or gender non-conforming    41787.000000
#           Woman                                                90735.333333
# 4.0       Man                                                  70569.027641
#           Non-binary, genderqueer, or gender non-conforming    61867.444444
#           Woman                                               100199.828358
# 5.0       Man                                                  73905.901373
#           Non-binary, genderqueer, or gender non-conforming    36535.300000
#           Woman                                                76862.532967
# 6.0       Man                                                  82660.724434
#           Non-binary, genderqueer, or gender non-conforming   117406.076923
#           Woman                                                70691.022346
# 7.0       Man                                                  81281.301989
#           Non-binary, genderqueer, or gender non-conforming   144692.538462
#           Woman                                                87140.171975
# 8.0       Man                                                  86361.004016
#           Non-binary, genderqueer, or gender non-conforming   137036.650000
#           Woman                                                87474.786667
# 9.0       Man                                                  80888.888976
#           Non-binary, genderqueer, or gender non-conforming    82913.076923
#           Woman                                                74098.504425
# ...                                                                     ...
# 38.0      Man                                                 187057.290503
#           Non-binary, genderqueer, or gender non-conforming   580000.000000
#           Woman                                               151395.000000
# 39.0      Man                                                 163431.978261
#           Woman                                               207891.333333
# 40.0      Man                                                 151459.761290
#           Non-binary, genderqueer, or gender non-conforming   972883.000000
#           Woman                                               273417.166667
# 41.0      Man                                                 210234.274194
#           Woman                                               137000.000000
# 42.0      Man                                                 167024.264706
#           Non-binary, genderqueer, or gender non-conforming             NaN
#           Woman                                               383901.333333
# 43.0      Man                                                 158448.636364
#           Non-binary, genderqueer, or gender non-conforming   126500.000000
#           Woman                                                         NaN
# 44.0      Man                                                 142537.194444
#           Woman                                               172500.000000
# 45.0      Man                                                 160375.540000
#           Woman                                                64860.000000
# 46.0      Man                                                 277916.666667
#           Woman                                                         NaN
# 47.0      Man                                                 328376.571429
#           Woman                                                60000.000000
# 48.0      Man                                                  95698.352941
#           Woman                                                         NaN
# 49.0      Man                                                 107718.000000
# 50.0      Man                                                 141032.847458
#           Non-binary, genderqueer, or gender non-conforming   150000.000000
#           Woman                                              1000000.000000
#
# [141 rows x 1 columns]

# %%
df = df[df.Sexuality.isin(['Gay or Lesbian','Bisexual','Straight / Heterosexual'])]
df1 = df.groupby(['YearsCode','Gender'])['ConvertedComp'].mean().to_frame()

# %%
7/5
# Out:
# 1.4

# %%
7//5
# Out:
# 1

# %%
(16//5)*5
# Out:
# 15

# %%
df.groupby(['Sexuality'])['Respondent'].count().plot.bar()

# %%
df_temp = df[df.Country == 'United States']
df_reg = df_temp[['Age','ConvertedComp','Gender','Ethnicity', 'YearsCodePro', 'Sexuality']]
df_reg["YearsCodePro"].replace({"Less than 1 year": 0, "More than 50 years":50}, inplace=True)
df_reg["YearsCodePro"] = df_reg["YearsCodePro"].apply(pd.to_numeric)
# Out:
# /Users/Mickkygoel/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6586: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /Users/Mickkygoel/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_reg.dropna()
# Out:
#         Age  ConvertedComp                                             Gender  \
# 7      36.0       116000.0                                                Man
# 13     27.0        66000.0                                                Man
# 16     25.0        79000.0                                                Man
# 17     32.0      1260000.0                                                Man
# 18     24.0        83400.0                                                Man
# 41     32.0       130000.0                                                Man
# 47     38.0       125000.0                                                Man
# 48     23.0        52000.0                                                Man
# 56     44.0      1620000.0                                                Man
# 64     34.0      1176000.0                                                Man
# 66     35.0       250000.0                                                Man
# 79     32.0        94500.0                                                Man
# 88     28.0       130000.0                                              Woman
# 98     42.0        93000.0  Man;Non-binary, genderqueer, or gender non-con...
# 103    28.0        40000.0                                                Man
# 105    29.0       148000.0                                              Woman
# 108    45.0       130000.0                                                Man
# 110    28.0        65000.0                                                Man
# 113    23.0        78800.0                                                Man
# 117    35.0       145000.0                                                Man
# 119    26.0       145000.0                                                Man
# 121    26.0      2000000.0                                                Man
# 122    38.0            0.0                                                Man
# 123    41.0      2000000.0                                                Man
# 124    35.0       145000.0                                                Man
# 126    23.0        80000.0                                              Woman
# 129    37.0       115000.0                                                Man
# 136    25.0       215000.0                                                Man
# 137    30.0        45000.0                                              Woman
# 140    27.0        53000.0                                                Man
# ...     ...            ...                                                ...
# 61479  35.0        95000.0                                                Man
# 61482  22.0        65000.0                                                Man
# 61495  40.0       102000.0                                                Man
# 61497  21.0        70000.0                                                Man
# 61500  32.0       120000.0                                                Man
# 61501  31.0       160000.0                                                Man
# 61515  27.0        95000.0                                                Man
# 61538  31.0       120000.0                                                Man
# 61549  28.0       102000.0                                                Man
# 61555  44.0       106000.0                                              Woman
# 61556  36.0        70000.0                                                Man
# 61558  36.0       120000.0                                                Man
# 61564  40.0       145000.0                                                Man
# 61579  24.0       118000.0                                              Woman
# 61596  30.0        72000.0                                                Man
# 61597  25.0       166000.0                                                Man
# 61605  47.0       310000.0                                                Man
# 61607  39.0       179004.0                                                Man
# 61610  52.0       280000.0                                                Man
# 61613  30.0       230000.0                                                Man
# 61614  27.0        53000.0                                                Man
# 61616  38.0       200000.0                                                Man
# 61621  34.0       150000.0                                                Man
# 61632  28.0       180000.0                                                Man
# 61636  32.0       102700.0                                                Man
# 61643  29.0        97500.0                                                Man
# 61654  33.0        95000.0                                                Man
# 61657  33.0        61000.0                                                Man
# 61658  43.0       170000.0                                                Man
# 61663  33.0        55000.0                                              Woman
#
#                                                Ethnicity  YearsCodePro  \
# 7                           White or of European descent          13.0
# 13                          White or of European descent           1.0
# 16                          White or of European descent           3.0
# 17                          White or of European descent          12.0
# 18                          White or of European descent           3.0
# 41                          White or of European descent          10.0
# 47                          White or of European descent           8.0
# 48                          White or of European descent           4.0
# 56                          White or of European descent          23.0
# 64                          White or of European descent          14.0
# 66                          White or of European descent          15.0
# 79     Hispanic or Latino/a/x;White or of European de...           7.0
# 88                          White or of European descent           2.0
# 98                          White or of European descent          11.0
# 103                         White or of European descent           0.0
# 105                         White or of European descent           5.0
# 108                                          South Asian          21.0
# 110                                          South Asian           3.0
# 113                         White or of European descent           2.0
# 117                         White or of European descent          16.0
# 119              East Asian;White or of European descent           5.0
# 121                         White or of European descent           3.0
# 122                         White or of European descent          19.0
# 123                         White or of European descent          11.0
# 124                         White or of European descent           4.0
# 126                         White or of European descent           4.0
# 129                         White or of European descent           3.0
# 136                                      Southeast Asian           2.0
# 137                         White or of European descent           8.0
# 140                               Hispanic or Latino/a/x           1.0
# ...                                                  ...           ...
# 61479                       White or of European descent           2.0
# 61482                        Black or of African descent           2.0
# 61495  Hispanic or Latino/a/x;White or of European de...          20.0
# 61497                       White or of European descent           1.0
# 61500                       White or of European descent          13.0
# 61501                       White or of European descent          10.0
# 61515                       White or of European descent           4.0
# 61538                                         East Asian           5.0
# 61549                       White or of European descent           9.0
# 61555            East Asian;White or of European descent          25.0
# 61556                       White or of European descent          10.0
# 61558                       White or of European descent           9.0
# 61564                       White or of European descent          20.0
# 61579                                    Southeast Asian           2.0
# 61596                       White or of European descent           5.0
# 61597                       White or of European descent           2.0
# 61605                       White or of European descent           0.0
# 61607                       White or of European descent          19.0
# 61610                       White or of European descent          36.0
# 61613                       White or of European descent           7.0
# 61614                       White or of European descent           3.0
# 61616                       White or of European descent          13.0
# 61621                                         East Asian           4.0
# 61632                                        South Asian           5.0
# 61636                       White or of European descent           5.0
# 61643  Hispanic or Latino/a/x;White or of European de...           5.0
# 61654                       White or of European descent           7.0
# 61657                       White or of European descent           0.0
# 61658                             Hispanic or Latino/a/x           3.0
# 61663                       White or of European descent           0.0
#
#                            Sexuality
# 7            Straight / Heterosexual
# 13           Straight / Heterosexual
# 16           Straight / Heterosexual
# 17           Straight / Heterosexual
# 18           Straight / Heterosexual
# 41           Straight / Heterosexual
# 47           Straight / Heterosexual
# 48           Straight / Heterosexual
# 56           Straight / Heterosexual
# 64           Straight / Heterosexual
# 66           Straight / Heterosexual
# 79           Straight / Heterosexual
# 88           Straight / Heterosexual
# 98                    Bisexual;Queer
# 103          Straight / Heterosexual
# 105                   Gay or Lesbian
# 108          Straight / Heterosexual
# 110          Straight / Heterosexual
# 113          Straight / Heterosexual
# 117          Straight / Heterosexual
# 119          Straight / Heterosexual
# 121          Straight / Heterosexual
# 122          Straight / Heterosexual
# 123          Straight / Heterosexual
# 124          Straight / Heterosexual
# 126          Straight / Heterosexual
# 129          Straight / Heterosexual
# 136          Straight / Heterosexual
# 137             Gay or Lesbian;Queer
# 140          Straight / Heterosexual
# ...                              ...
# 61479        Straight / Heterosexual
# 61482        Straight / Heterosexual
# 61495        Straight / Heterosexual
# 61497        Straight / Heterosexual
# 61500        Straight / Heterosexual
# 61501        Straight / Heterosexual
# 61515        Straight / Heterosexual
# 61538        Straight / Heterosexual
# 61549        Straight / Heterosexual
# 61555                 Gay or Lesbian
# 61556        Straight / Heterosexual
# 61558        Straight / Heterosexual
# 61564        Straight / Heterosexual
# 61579  Bisexual;Gay or Lesbian;Queer
# 61596        Straight / Heterosexual
# 61597        Straight / Heterosexual
# 61605        Straight / Heterosexual
# 61607        Straight / Heterosexual
# 61610        Straight / Heterosexual
# 61613        Straight / Heterosexual
# 61614        Straight / Heterosexual
# 61616        Straight / Heterosexual
# 61621        Straight / Heterosexual
# 61632        Straight / Heterosexual
# 61636        Straight / Heterosexual
# 61643        Straight / Heterosexual
# 61654        Straight / Heterosexual
# 61657        Straight / Heterosexual
# 61658        Straight / Heterosexual
# 61663        Straight / Heterosexual
#
# [6571 rows x 6 columns]

# %%
len(df_reg)
# Out:
# 12469

# %%
df_reg.loc[~df.Gender.isin(['Man','Woman']), 'Gender'] = 'Non-binary'
df_reg.loc[~df.Sexuality.isin(['Straight / Heterosexual']), 'Sexuality'] = 'Other'
df_reg.loc[~df.Ethnicity.isin(['White or of European descent']), 'Ethnicity'] = 'Other'

# %%
Gender_encode = pd.get_dummies(df_reg['Gender'])
Sexuality_encode = pd.get_dummies(df_reg['Sexuality'], prefix='Sexuality')
Ethnicity_encode = pd.get_dummies(df_reg['Ethnicity'], prefix='Ethnicity')
df_reg = df_reg.join(Gender_encode)
df_reg = df_reg.join(Sexuality_encode)
df_reg = df_reg.join(Ethnicity_encode)

# %%
df_reg
# Out:
#         Age  ConvertedComp      Gender                     Ethnicity  \
# 4      31.0            NaN         Man  White or of European descent
# 7      36.0       116000.0         Man  White or of European descent
# 13     27.0        66000.0         Man  White or of European descent
# 16     25.0        79000.0         Man  White or of European descent
# 17     32.0      1260000.0         Man  White or of European descent
# 18     24.0        83400.0         Man  White or of European descent
# 26      NaN            NaN         Man  White or of European descent
# 34     16.0            NaN       Woman  White or of European descent
# 39     20.0            NaN       Woman                         Other
# 40      NaN       106000.0  Non-binary                         Other
# 41     32.0       130000.0         Man  White or of European descent
# 42      NaN       135000.0  Non-binary                         Other
# 47     38.0       125000.0         Man  White or of European descent
# 48     23.0        52000.0         Man  White or of European descent
# 52     17.0            NaN         Man                         Other
# 53     44.0       160000.0         Man                         Other
# 54      NaN            NaN         Man                         Other
# 55     27.0            NaN       Woman  White or of European descent
# 56     44.0      1620000.0         Man  White or of European descent
# 64     34.0      1176000.0         Man  White or of European descent
# 66     35.0       250000.0         Man  White or of European descent
# 67     20.0            NaN         Man  White or of European descent
# 71     25.0            NaN         Man  White or of European descent
# 75     19.0            NaN         Man  White or of European descent
# 76      NaN            NaN         Man  White or of European descent
# 79     32.0        94500.0         Man                         Other
# 80     18.0            NaN         Man  White or of European descent
# 81     48.0       117000.0         Man  White or of European descent
# 83     25.0            NaN         Man  White or of European descent
# 84     21.0            NaN       Woman  White or of European descent
# ...     ...            ...         ...                           ...
# 64165   NaN            NaN  Non-binary                         Other
# 64167   NaN            NaN       Woman  White or of European descent
# 64170  45.0            NaN         Man                         Other
# 64173   NaN            NaN  Non-binary                         Other
# 64174  24.0            NaN         Man  White or of European descent
# 64178   NaN            NaN  Non-binary                         Other
# 64223  21.0            NaN         Man  White or of European descent
# 64229   NaN            NaN         Man  White or of European descent
# 64237  39.0            NaN         Man  White or of European descent
# 64285   NaN            NaN  Non-binary  White or of European descent
# 64292   NaN            NaN  Non-binary                         Other
# 64296   NaN            NaN  Non-binary                         Other
# 64300   NaN            NaN  Non-binary                         Other
# 64330   NaN            NaN  Non-binary                         Other
# 64340   NaN            NaN  Non-binary                         Other
# 64347   NaN            NaN  Non-binary                         Other
# 64352   NaN            NaN  Non-binary                         Other
# 64354   NaN            NaN  Non-binary                         Other
# 64356  22.0            NaN         Man                         Other
# 64368  32.0            NaN         Man                         Other
# 64382   NaN            NaN         Man  White or of European descent
# 64385  26.0            NaN         Man  White or of European descent
# 64386  30.0            NaN         Man  White or of European descent
# 64387  24.0            NaN         Man                         Other
# 64388  56.0            NaN         Man                         Other
# 64413  32.0            NaN         Man  White or of European descent
# 64417  29.0            NaN         Man  White or of European descent
# 64428   NaN            NaN         Man                         Other
# 64443   NaN            NaN  Non-binary                         Other
# 64456   NaN            NaN  Non-binary                         Other
#
#        YearsCodePro                Sexuality  Man  Non-binary  Woman  \
# 4               8.0  Straight / Heterosexual    1           0      0
# 7              13.0  Straight / Heterosexual    1           0      0
# 13              1.0  Straight / Heterosexual    1           0      0
# 16              3.0  Straight / Heterosexual    1           0      0
# 17             12.0  Straight / Heterosexual    1           0      0
# 18              3.0  Straight / Heterosexual    1           0      0
# 26             20.0  Straight / Heterosexual    1           0      0
# 34              NaN  Straight / Heterosexual    0           0      1
# 39              NaN  Straight / Heterosexual    0           0      1
# 40             20.0                    Other    0           1      0
# 41             10.0  Straight / Heterosexual    1           0      0
# 42             29.0                    Other    0           1      0
# 47              8.0  Straight / Heterosexual    1           0      0
# 48              4.0  Straight / Heterosexual    1           0      0
# 52              3.0  Straight / Heterosexual    1           0      0
# 53             23.0                    Other    1           0      0
# 54              NaN  Straight / Heterosexual    1           0      0
# 55              4.0  Straight / Heterosexual    0           0      1
# 56             23.0  Straight / Heterosexual    1           0      0
# 64             14.0  Straight / Heterosexual    1           0      0
# 66             15.0  Straight / Heterosexual    1           0      0
# 67              NaN  Straight / Heterosexual    1           0      0
# 71              NaN  Straight / Heterosexual    1           0      0
# 75              NaN  Straight / Heterosexual    1           0      0
# 76             16.0  Straight / Heterosexual    1           0      0
# 79              7.0  Straight / Heterosexual    1           0      0
# 80              NaN  Straight / Heterosexual    1           0      0
# 81             25.0                    Other    1           0      0
# 83              2.0  Straight / Heterosexual    1           0      0
# 84              1.0                    Other    0           0      1
# ...             ...                      ...  ...         ...    ...
# 64165           NaN                    Other    0           1      0
# 64167           0.0                    Other    0           0      1
# 64170           0.0  Straight / Heterosexual    1           0      0
# 64173          10.0                    Other    0           1      0
# 64174           NaN  Straight / Heterosexual    1           0      0
# 64178           0.0                    Other    0           1      0
# 64223           NaN  Straight / Heterosexual    1           0      0
# 64229          15.0  Straight / Heterosexual    1           0      0
# 64237           NaN  Straight / Heterosexual    1           0      0
# 64285           NaN                    Other    0           1      0
# 64292           NaN                    Other    0           1      0
# 64296           0.0                    Other    0           1      0
# 64300           NaN                    Other    0           1      0
# 64330           NaN                    Other    0           1      0
# 64340           4.0                    Other    0           1      0
# 64347           NaN                    Other    0           1      0
# 64352           NaN                    Other    0           1      0
# 64354           NaN                    Other    0           1      0
# 64356           NaN  Straight / Heterosexual    1           0      0
# 64368          10.0  Straight / Heterosexual    1           0      0
# 64382           NaN  Straight / Heterosexual    1           0      0
# 64385           1.0  Straight / Heterosexual    1           0      0
# 64386           3.0  Straight / Heterosexual    1           0      0
# 64387           NaN                    Other    1           0      0
# 64388           NaN                    Other    1           0      0
# 64413           0.0  Straight / Heterosexual    1           0      0
# 64417           NaN                    Other    1           0      0
# 64428           NaN                    Other    1           0      0
# 64443           NaN                    Other    0           1      0
# 64456           0.0                    Other    0           1      0
#
#        Sexuality_Other  Sexuality_Straight / Heterosexual  Ethnicity_Other  \
# 4                    0                                  1                0
# 7                    0                                  1                0
# 13                   0                                  1                0
# 16                   0                                  1                0
# 17                   0                                  1                0
# 18                   0                                  1                0
# 26                   0                                  1                0
# 34                   0                                  1                0
# 39                   0                                  1                1
# 40                   1                                  0                1
# 41                   0                                  1                0
# 42                   1                                  0                1
# 47                   0                                  1                0
# 48                   0                                  1                0
# 52                   0                                  1                1
# 53                   1                                  0                1
# 54                   0                                  1                1
# 55                   0                                  1                0
# 56                   0                                  1                0
# 64                   0                                  1                0
# 66                   0                                  1                0
# 67                   0                                  1                0
# 71                   0                                  1                0
# 75                   0                                  1                0
# 76                   0                                  1                0
# 79                   0                                  1                1
# 80                   0                                  1                0
# 81                   1                                  0                0
# 83                   0                                  1                0
# 84                   1                                  0                0
# ...                ...                                ...              ...
# 64165                1                                  0                1
# 64167                1                                  0                0
# 64170                0                                  1                1
# 64173                1                                  0                1
# 64174                0                                  1                0
# 64178                1                                  0                1
# 64223                0                                  1                0
# 64229                0                                  1                0
# 64237                0                                  1                0
# 64285                1                                  0                0
# 64292                1                                  0                1
# 64296                1                                  0                1
# 64300                1                                  0                1
# 64330                1                                  0                1
# 64340                1                                  0                1
# 64347                1                                  0                1
# 64352                1                                  0                1
# 64354                1                                  0                1
# 64356                0                                  1                1
# 64368                0                                  1                1
# 64382                0                                  1                0
# 64385                0                                  1                0
# 64386                0                                  1                0
# 64387                1                                  0                1
# 64388                1                                  0                1
# 64413                0                                  1                0
# 64417                1                                  0                0
# 64428                1                                  0                1
# 64443                1                                  0                1
# 64456                1                                  0                1
#
#        Ethnicity_White or of European descent
# 4                                           1
# 7                                           1
# 13                                          1
# 16                                          1
# 17                                          1
# 18                                          1
# 26                                          1
# 34                                          1
# 39                                          0
# 40                                          0
# 41                                          1
# 42                                          0
# 47                                          1
# 48                                          1
# 52                                          0
# 53                                          0
# 54                                          0
# 55                                          1
# 56                                          1
# 64                                          1
# 66                                          1
# 67                                          1
# 71                                          1
# 75                                          1
# 76                                          1
# 79                                          0
# 80                                          1
# 81                                          1
# 83                                          1
# 84                                          1
# ...                                       ...
# 64165                                       0
# 64167                                       1
# 64170                                       0
# 64173                                       0
# 64174                                       1
# 64178                                       0
# 64223                                       1
# 64229                                       1
# 64237                                       1
# 64285                                       1
# 64292                                       0
# 64296                                       0
# 64300                                       0
# 64330                                       0
# 64340                                       0
# 64347                                       0
# 64352                                       0
# 64354                                       0
# 64356                                       0
# 64368                                       0
# 64382                                       1
# 64385                                       1
# 64386                                       1
# 64387                                       0
# 64388                                       0
# 64413                                       1
# 64417                                       1
# 64428                                       0
# 64443                                       0
# 64456                                       0
#
# [12469 rows x 13 columns]

# %%
df_reg = df_reg[['ConvertedComp','Age','YearsCodePro','Woman','Non-binary','Sexuality_Other','Ethnicity_Other']]

# %%
df_reg.head()
# Out:
#     ConvertedComp   Age  YearsCodePro  Woman  Non-binary  Sexuality_Other  \
# 4             NaN  31.0           8.0      0           0                0
# 7        116000.0  36.0          13.0      0           0                0
# 13        66000.0  27.0           1.0      0           0                0
# 16        79000.0  25.0           3.0      0           0                0
# 17      1260000.0  32.0          12.0      0           0                0
#
#     Ethnicity_Other
# 4                 0
# 7                 0
# 13                0
# 16                0
# 17                0

# %%
df_reg = df_reg.rename(columns={"Non-binary": "Non_binary"})

# %%
df_reg = df_reg.dropna()

# %%
import statsmodels.formula.api as sm
result = sm.ols(formula="ConvertedComp ~ Age + YearsCodePro + Woman + Non_binary + Sexuality_Other + Ethnicity_Other", data=df_reg).fit()
print(result.params)
# Out:
# Intercept          223971.052765
# Age                  -851.778608
# YearsCodePro         1302.521214
# Woman              -36547.365480
# Non_binary         -21289.831398
# Sexuality_Other     -7155.384594
# Ethnicity_Other     14205.333189
# dtype: float64

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          ConvertedComp   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.414
# Date:                Sun, 29 Nov 2020   Prob (F-statistic):             0.0339
# Time:                        02:35:04   Log-Likelihood:            -1.0268e+05
# No. Observations:                7215   AIC:                         2.054e+05
# Df Residuals:                    7209   BIC:                         2.054e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         2.24e+05   2.21e+04     10.143      0.000    1.81e+05    2.67e+05
# Age              -862.8084    830.482     -1.039      0.299   -2490.796     765.179
# YearsCodePro     1324.0575    903.436      1.466      0.143    -446.943    3095.058
# Woman           -3.467e+04    1.5e+04     -2.311      0.021   -6.41e+04   -5262.671
# Sexuality_Other -1.093e+04   1.17e+04     -0.935      0.350   -3.39e+04     1.2e+04
# Ethnicity_Other  1.371e+04   1.04e+04      1.320      0.187   -6646.112    3.41e+04
# ==============================================================================
# Omnibus:                     6017.084   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           103984.285
# Skew:                           4.173   Prob(JB):                         0.00
# Kurtosis:                      19.620   Cond. No.                         194.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
